# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random
# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
options=['stone','paper','scissors']
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
max_nr_of_games = 5
# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
import math
games_to_win = math.ceil(max_nr_of_games/2)
# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def randomoption():
    return random.choice(options)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def yourchoice():
    choice = input("What's your choice?")
    if (choice == 'stone') | (choice == 'paper') | (choice == 'scissors'):
        choice = choice
    else:
        choice = input("Chose only stone, paper or scissorcs, please!")
    return choice

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def combat():
    human = yourchoice()
    machine = randomoption()
    if (human == machine):
        return 0
    elif (human == 'stone') & (machine == 'scissors'):
        return 2
    elif (human == 'stone') & (machine == 'paper'):
        return 1
    elif (human == 'paper') & (machine == 'scissors'):
        return 1
    elif (human == 'paper') & (machine == 'stone'):
        return 2
    elif (human == 'scissors') & (machine == 'stone'):
        return 1
    elif (human == 'scissors') & (machine == 'paper'):
        return 2
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def choiceandstate():
    human = yourchoice()
    machine = randomoption()
    if (human == machine):
        return [0, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'stone') & (machine == 'scissors'):
        return [2, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'stone') & (machine == 'paper'):
        return [1, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'paper') & (machine == 'scissors'):
        return [1, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'paper') & (machine == 'stone'):
        return [2, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'scissors') & (machine == 'stone'):
        return [1, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'scissors') & (machine == 'paper'):
        return [2, "Human selected:", human, "Machine selected:", machine]
    
# Create two variables that accumulate the wins of each participant
human_wins = 0
machine_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while((human_wins<games_to_win)&(machine_wins<games_to_win)):
    play=combat()
    if play == 2:
        machine_wins+=1
    elif play == 1:
        human_wins+=1
        

    
# Print by console the winner of the game based on who has more accumulated wins
if(human_wins>machine_wins):
    print("Human wins.")
else:
    print("Machine wins.")

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def oddnr():
    nr_of_games=int(input("How many games would you like to play?"))
    while((nr_of_games%2 == 0)):
        nr_of_games = int(input("Please tell us, how many games you would like to play, but be aware, that it has to be an odd number."))    
    return nr_of_games

# Assign a list of 5 possible options.
options_adv=['stone', 'paper', 'scissors', 'lizard', 'spock']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
max_nr_of_games_adv=oddnr()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
games_to_win_adv = math.ceil(max_nr_of_games_adv/2)

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def randomoption_adv():
    return random.choice(options_adv)

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def yourchoice_adv():
    choice = input("What's your choice?")
    if (choice == 'stone') | (choice == 'paper') | (choice == 'scissors') | (choice == 'lizard') | (choice == 'spock'):
        choice = choice
    else:
        choice = input("Chose only stone, paper, scissorcs, lizard or spock please!")
    return choice


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def choiceandstate_adv():
    human = yourchoice_adv()
    machine = randomoption_adv()
    if (human == machine):
        return [0, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'stone') & (machine == 'scissors') | (machine == 'lizard'):
        return [2, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'stone') & (machine == 'paper') | (machine == 'spock'):
        return [1, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'paper') & (machine == 'scissors') | (machine == 'lizard'):
        return [1, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'paper') & (machine == 'stone') | (machine == 'spock'):
        return [2, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'scissors') & (machine == 'stone') | (machine == 'spock'):
        return [1, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'scissors') & (machine == 'paper') | (machine == 'lizard'):
        return [2, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'lizard') & (machine == 'stone') | (machine == 'scissors'):
        return [1, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'lizard') & (machine == 'paper') | (machine == 'spock'):
        return [2, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'spock') & (machine == 'lizard') | (machine == 'paper'): 
        return [1, "Human selected:", human, "Machine selected:", machine]
    elif (human == 'spock') & (machine == 'stone') | (machine == 'scissors'):
        return [2, "Human selected:", human, "Machine selected:", machine]

    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def combat_adv():
    human = yourchoice_adv()
    machine = randomoption_adv()
    if (human == machine):
        return 0
    elif (human == 'stone') & (machine == 'scissors') | (machine == 'lizard'):
        return 2
    elif (human == 'stone') & (machine == 'paper') | (machine == 'spock'):
        return 1
    elif (human == 'paper') & (machine == 'scissors') | (machine == 'lizard'):
        return 1
    elif (human == 'paper') & (machine == 'stone') | (machine == 'spock'):
        return 2
    elif (human == 'scissors') & (machine == 'stone') | (machine == 'spock'):
        return 1
    elif (human == 'scissors') & (machine == 'paper') | (machine == 'lizard'):
        return 2
    elif (human == 'lizard') & (machine == 'stone') | (machine == 'scissors'):
        return 1
    elif (human == 'lizard') & (machine == 'paper') | (machine == 'spock'):
        return 2
    elif (human == 'spock') & (machine == 'lizard') | (machine == 'paper'): 
        return 1
    elif (human == 'spock') & (machine == 'stone') | (machine == 'scissors'):
        return 2

    
# Create two variables that accumulate the wins of each participant
human_wins_adv = 0
machine_wins_adv = 0
# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while((human_wins_adv<games_to_win_adv)&(machine_wins_adv<games_to_win_adv)):
    play=combat_adv()
    if play == 2:
        machine_wins_adv+=1
    elif play == 1:
        human_wins_adv+=1
    
    
# Print by console the winner of the game based on who has more accumulated wins
if(human_wins_adv>machine_wins_adv):
    print("Human wins.")
else:
    print("Machine wins.")
